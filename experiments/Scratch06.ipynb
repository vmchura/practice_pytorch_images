# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
import zipfile
import os
from torch.utils.data import DataLoader
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt
from torch.utils.data import Dataset

# %%
checkpoint_path = '/home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth'
metrics_path = "/home/vmchura/data/009.ImageProcessing/training_metrics_scratch_06.json"

# %%
train_transform = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.1), # Increased jitter
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1), scale=(0.9, 1.1)), # Added scaling
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2470, 0.2435, 0.2616)) # Correct CIFAR-10 normalization
])

test_transform = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2470, 0.2435, 0.2616))
])



train_dataset = datasets.ImageFolder(root="/home/vmchura/data/009.ImageProcessing/dataset_CIFAR10/train", transform=train_transform)
test_dataset = datasets.ImageFolder(root="/home/vmchura/data/009.ImageProcessing/dataset_CIFAR10/validation", transform=test_transform)

# %%
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=32, shuffle=False)


class ImageClassifier(nn.Module):
    def __init__(self, num_classes=10):
        super(ImageClassifier, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.relu1 = nn.ReLU()
        self.bn1 = nn.BatchNorm2d(64)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.relu2 = nn.ReLU()
        self.bn2 = nn.BatchNorm2d(128)
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.relu3 = nn.ReLU()
        self.bn3 = nn.BatchNorm2d(256)
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.fc1 = nn.Linear(256 * 4 * 4, 512)
        self.relu4 = nn.ReLU()
        self.dropout1 = nn.Dropout(0.5)
        self.fc2 = nn.Linear(512, num_classes)

    def forward(self, x):
        x = self.pool1(self.bn1(self.relu1(self.conv1(x))))
        x = self.pool2(self.bn2(self.relu2(self.conv2(x))))
        x = self.pool3(self.bn3(self.relu3(self.conv3(x))))
        x = x.view(-1, 256 * 4 * 4)
        x = self.dropout1(self.relu4(self.fc1(x)))
        x = self.fc2(x)
        return x

    def predict(self, x):
        return torch.softmax(self.forward(x), dim=1)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(train_dataset.classes)
criterion = nn.CrossEntropyLoss()
# Out:
# ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
def train_iteration(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    average_loss = 0
    average_accuracy = 0
    for images, labels in dataloader:
        images, labels = images.to(device), labels.to(device)
        predictions = model(images)
        loss = loss_fn(predictions, labels)
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        average_loss += loss.item()
        average_accuracy += (predictions.argmax(1) == labels).type(torch.float).sum().item()

    average_loss /= len(dataloader)
    average_accuracy /= size
    return {'average_loss': average_loss, 'average_accuracy': average_accuracy}

def test_iteration(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    average_loss = 0
    average_accuracy = 0
    with torch.no_grad():
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            predictions = model(images)
            average_loss += loss_fn(predictions, labels).item()
            average_accuracy += (predictions.argmax(1) == labels).type(torch.float).sum().item()
    average_loss /= num_batches
    average_accuracy /= size
    return {'average_loss': average_loss, 'average_accuracy': average_accuracy}

# %%
model = ImageClassifier(num_classes=len(train_dataset.classes)).to(device)
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)

try:
    checkpoint = torch.load(checkpoint_path)
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    start_epoch = checkpoint['epoch']
    print(f"Resuming training from epoch {start_epoch}")
except FileNotFoundError:
    print("No checkpoint found. Starting training from scratch.")
    start_epoch = 0
# Out:
# Resuming training from epoch 5

# %%
import json

def save_metrics(epoch, train_results, test_results, filename):
    try:
        with open(filename, 'r') as f:
            metrics = json.load(f)
    except FileNotFoundError:
        metrics = []

    metrics.append({
        'epoch': epoch + 1,
        'train_loss': train_results['average_loss'],
        'train_accuracy': train_results['average_accuracy'],
        'test_loss': test_results['average_loss'],
        'test_accuracy': test_results['average_accuracy']
    })

    with open(filename, 'w') as f:
        json.dump(metrics, f, indent=4)

# %%
num_epochs = 60
for epoch in range(start_epoch, num_epochs):
    print(f"Epoch {epoch+1}\n-------------------------------")
    train_results = train_iteration(train_loader, model, criterion, optimizer)
    test_results = test_iteration(test_loader, model, criterion)
    save_metrics(epoch, train_results, test_results, metrics_path)
    print("Metrics saved to training_metrics_scratch_06.json")
    print(f"Train Loss: {train_results['average_loss']}, Train Accuracy: {train_results['average_accuracy']}")
    print(f"Test Loss: {test_results['average_loss']}, Test Accuracy: {test_results['average_accuracy']}")
    # Save model state after each epoch
    checkpoint = {
        'epoch': epoch + 1,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'train_loss': train_results['average_loss'],
        'train_accuracy': train_results['average_accuracy'],
        'test_loss': test_results['average_loss'],
        'test_accuracy': test_results['average_accuracy']
    }
    torch.save(checkpoint, checkpoint_path)
    print(f"Checkpoint saved at {checkpoint_path}")

print("Finished Training")
# Out:
# Epoch 6
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 1.1019086255788804, Train Accuracy: 0.621475
# Test Loss: 0.802418873618586, Test Accuracy: 0.7264
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 7
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 1.04795581138134, Train Accuracy: 0.64035
# Test Loss: 0.7530800975597324, Test Accuracy: 0.7427
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 8
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 1.0065943698883058, Train Accuracy: 0.6522
# Test Loss: 0.7397101495664912, Test Accuracy: 0.7494
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 9
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.9880403145074844, Train Accuracy: 0.66255
# Test Loss: 0.7131363446244036, Test Accuracy: 0.7571
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 10
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.9544457920312881, Train Accuracy: 0.6713
# Test Loss: 0.7082469897767225, Test Accuracy: 0.7588
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 11
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.9267427051067352, Train Accuracy: 0.67965
# Test Loss: 0.6904434380582727, Test Accuracy: 0.7703
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 12
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.9091497404336929, Train Accuracy: 0.687175
# Test Loss: 0.6643492356656839, Test Accuracy: 0.7736
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 13
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.8863246356487274, Train Accuracy: 0.694675
# Test Loss: 0.6496215334025245, Test Accuracy: 0.7816
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 14
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.8696105643510819, Train Accuracy: 0.698975
# Test Loss: 0.657408571924074, Test Accuracy: 0.7792
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 15
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.8506813251972198, Train Accuracy: 0.707675
# Test Loss: 0.6405173278987979, Test Accuracy: 0.7784
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 16
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.8435735413074493, Train Accuracy: 0.709575
# Test Loss: 0.6467035057576606, Test Accuracy: 0.7746
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 17
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.8242642164945603, Train Accuracy: 0.715275
# Test Loss: 0.6250395790551798, Test Accuracy: 0.7873
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 18
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.8205240565776825, Train Accuracy: 0.71685
# Test Loss: 0.60433094593854, Test Accuracy: 0.7948
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 19
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.8061728095531464, Train Accuracy: 0.7209
# Test Loss: 0.6121765022960525, Test Accuracy: 0.7933
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 20
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.8017627210617065, Train Accuracy: 0.7236
# Test Loss: 0.6004854449496483, Test Accuracy: 0.7922
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 21
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.790840576338768, Train Accuracy: 0.7289
# Test Loss: 0.5913220947078718, Test Accuracy: 0.798
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 22
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.7790515600085258, Train Accuracy: 0.729125
# Test Loss: 0.6080578386831207, Test Accuracy: 0.7969
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 23
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.7785847760915756, Train Accuracy: 0.7303
# Test Loss: 0.6118413003060383, Test Accuracy: 0.792
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 24
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.7775128941297531, Train Accuracy: 0.734
# Test Loss: 0.603177240886056, Test Accuracy: 0.7951
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 25
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.767371858048439, Train Accuracy: 0.733075
# Test Loss: 0.5764988353267645, Test Accuracy: 0.7975
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 26
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.770583486199379, Train Accuracy: 0.735725
# Test Loss: 0.5884441180160632, Test Accuracy: 0.7962
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 27
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.7569314806938171, Train Accuracy: 0.73805
# Test Loss: 0.591061853776915, Test Accuracy: 0.7983
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 28
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.7575048486948013, Train Accuracy: 0.7386
# Test Loss: 0.5929137824680477, Test Accuracy: 0.7978
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 29
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.7488452626228332, Train Accuracy: 0.73985
# Test Loss: 0.5755856296005911, Test Accuracy: 0.8017
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 30
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.7442540340781212, Train Accuracy: 0.74145
# Test Loss: 0.5737756387875103, Test Accuracy: 0.8056
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 31
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.7441741286754608, Train Accuracy: 0.745625
# Test Loss: 0.5719849658540834, Test Accuracy: 0.8066
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 32
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.7412527238845825, Train Accuracy: 0.743975
# Test Loss: 0.5626152496570691, Test Accuracy: 0.8085
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 33
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.7353819242477417, Train Accuracy: 0.74735
# Test Loss: 0.6052049981733671, Test Accuracy: 0.8002
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 34
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.7297089994430542, Train Accuracy: 0.74845
# Test Loss: 0.5899922469624886, Test Accuracy: 0.7977
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 35
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.7282463686466217, Train Accuracy: 0.74765
# Test Loss: 0.561768878066835, Test Accuracy: 0.8099
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 36
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.7288535454034806, Train Accuracy: 0.7484
# Test Loss: 0.5712627942760151, Test Accuracy: 0.8056
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 37
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.725885921573639, Train Accuracy: 0.747375
# Test Loss: 0.549310541833742, Test Accuracy: 0.8135
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 38
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.7206958882927894, Train Accuracy: 0.751175
# Test Loss: 0.5339307438034695, Test Accuracy: 0.8184
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 39
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.7204593316078186, Train Accuracy: 0.750825
# Test Loss: 0.566147269270481, Test Accuracy: 0.805
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 40
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.719147380566597, Train Accuracy: 0.7516
# Test Loss: 0.5635289481153694, Test Accuracy: 0.8068
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 41
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.7178410574913024, Train Accuracy: 0.752175
# Test Loss: 0.5646362850984065, Test Accuracy: 0.809
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 42
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.7121806311368942, Train Accuracy: 0.75305
# Test Loss: 0.5984737493764287, Test Accuracy: 0.796
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 43
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.714642561006546, Train Accuracy: 0.753225
# Test Loss: 0.5653830015430816, Test Accuracy: 0.81
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 44
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.7105618121623993, Train Accuracy: 0.7541
# Test Loss: 0.5721548755947774, Test Accuracy: 0.8103
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 45
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.706452238559723, Train Accuracy: 0.756475
# Test Loss: 0.5658722532966647, Test Accuracy: 0.8158
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 46
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.7071519875526429, Train Accuracy: 0.7562
# Test Loss: 0.5650491514942422, Test Accuracy: 0.8126
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 47
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.7099121216773987, Train Accuracy: 0.755675
# Test Loss: 0.5699812277687338, Test Accuracy: 0.8038
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 48
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.7043956388950348, Train Accuracy: 0.75635
# Test Loss: 0.53719918193004, Test Accuracy: 0.8186
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 49
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.7083016200065613, Train Accuracy: 0.75505
# Test Loss: 0.5487935946415217, Test Accuracy: 0.8162
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 50
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.7085608523964881, Train Accuracy: 0.7561
# Test Loss: 0.5567665110571316, Test Accuracy: 0.8136
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 51
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.6999347044706344, Train Accuracy: 0.760625
# Test Loss: 0.543084488949551, Test Accuracy: 0.8178
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 52
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.7031378364920616, Train Accuracy: 0.75615
# Test Loss: 0.5730872813897868, Test Accuracy: 0.811
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 53
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.701070420897007, Train Accuracy: 0.75955
# Test Loss: 0.5527551153454536, Test Accuracy: 0.8156
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 54
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.7002620068550109, Train Accuracy: 0.759725
# Test Loss: 0.5455900663956286, Test Accuracy: 0.8197
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 55
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.6947160767793655, Train Accuracy: 0.760325
# Test Loss: 0.5688321348220206, Test Accuracy: 0.81
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 56
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.6965606034517288, Train Accuracy: 0.75965
# Test Loss: 0.5471640489519404, Test Accuracy: 0.8178
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 57
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.6993644750356675, Train Accuracy: 0.7605
# Test Loss: 0.5526813614173248, Test Accuracy: 0.8184
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 58
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.6953010283827782, Train Accuracy: 0.761125
# Test Loss: 0.5506003281940668, Test Accuracy: 0.8138
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 59
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.6879666115164756, Train Accuracy: 0.762675
# Test Loss: 0.5564753151358888, Test Accuracy: 0.8122
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Epoch 60
# -------------------------------
# Metrics saved to training_metrics_scratch_06.json
# Train Loss: 0.6904206942796707, Train Accuracy: 0.7624
# Test Loss: 0.5343829305074848, Test Accuracy: 0.8207
# Checkpoint saved at /home/vmchura/data/009.ImageProcessing/model_checkpoint_scratch_06.pth
# Finished Training
